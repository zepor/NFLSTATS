# %% [markdown]
# # Ship's Instruction Manual

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\johnb\website2\.venv\lib\site-packages (8.1.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\johnb\website2\.venv\lib\site-packages (from ipywidgets) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\johnb\website2\.venv\lib\site-packages (from ipywidgets) (8.16.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\johnb\website2\.venv\lib\site-packages (from ipywidgets) (5.12.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\johnb\website2\.venv\lib\site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\johnb\website2\.venv\lib\site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: backcall in c:\users\johnb\website2\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\johnb\website2\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\johnb\website2\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\johnb\website2\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\johnb\website2\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\johnb\website2\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\johnb\website2\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\johnb\website2\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions in c:\users\johnb\website2\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: exceptiongroup in c:\users\johnb\website2\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.3)
# Requirement already satisfied: colorama in c:\users\johnb\website2\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\johnb\website2\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\johnb\website2\.venv\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.8)
# Requirement already satisfied: executing>=1.2.0 in c:\users\johnb\website2\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\johnb\website2\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\johnb\website2\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\johnb\website2\.venv\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipywidgets as widgets

ignition = widgets.ToggleButton(
    value=False,
    description='Start Engine',
    button_style='success',
    tooltip='Engage your Engine',
    icon='rocket'
)

output = widgets.Output()

display(ignition, output)

def on_value_change(change):
    with output:
        if change['new'] == True:
            print("engine started!")
        else:   
            print("engine stopped")

ignition.observe(on_value_change, names='value')
# Out:
# ToggleButton(value=False, button_style='success', description='Start Engine', icon='rocket', tooltip='Engage y…
# Output()

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\johnb\website2\.venv\lib\site-packages (1.26.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.0-cp39-cp39-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.1.1-cp39-cp39-win_amd64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.43.1-cp39-cp39-win_amd64.whl.metadata (155 kB)
#      ---------------------------------------- 0.0/155.5 kB ? eta -:--:--
#      -------------------------------------- 155.5/155.5 kB 4.7 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp39-cp39-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\johnb\website2\.venv\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\johnb\website2\.venv\lib\site-packages (from matplotlib) (21.3)
# Collecting pillow>=6.2.0 (from matplotlib)
#   Downloading Pillow-10.1.0-cp39-cp39-win_amd64.whl.metadata (9.6 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\johnb\website2\.venv\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\johnb\website2\.venv\lib\site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Downloading importlib_resources-6.1.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\johnb\website2\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\johnb\website2\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.0-cp39-cp39-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.6 MB 10.2 MB/s eta 0:00:01
#    ------------ --------------------------- 2.3/7.6 MB 24.8 MB/s eta 0:00:01
#    --------------------------- ------------ 5.3/7.6 MB 37.5 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 44.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 37.6 MB/s eta 0:00:00
# Downloading contourpy-1.1.1-cp39-cp39-win_amd64.whl (435 kB)
#    ---------------------------------------- 0.0/436.0 kB ? eta -:--:--
#    ---------------------------------------- 436.0/436.0 kB ? eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.43.1-cp39-cp39-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 68.8 MB/s eta 0:00:00
# Downloading importlib_resources-6.1.0-py3-none-any.whl (33 kB)
# Downloading kiwisolver-1.4.5-cp39-cp39-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.2 kB ? eta -:--:--
#    ---------------------------------------- 56.2/56.2 kB ? eta 0:00:00
# Downloading Pillow-10.1.0-cp39-cp39-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 83.8 MB/s eta 0:00:00
# Installing collected packages: pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.43.1 importlib-resources-6.1.0 kiwisolver-1.4.5 matplotlib-3.8.0 pillow-10.1.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Oxygen levels
#
# Display ten minutes of oxygen levels in your ship.

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.default_rng(12345)
oxy_nums = data.integers(low=0, high=10, size=10)

plt.bar(range(len(oxy_nums)), oxy_nums)
plt.show()

# %% [markdown]
# ## Ship's velocity
#
# Show the seconds needed to get from 0 to 60 meters per second, given the ship's acceleration in meters per second.

# %%
endVelocity = 60
startVelocity = 0
acceleration = 9.8

time = (endVelocity - startVelocity) / acceleration
print("Time to reach desired velocity = ", time)
# Out:
# Time to reach desired velocity =  6.122448979591836
